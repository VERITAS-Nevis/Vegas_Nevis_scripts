# %%
# %matplotlib inline
from resolutionPlottingData import * 

filename = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_geo.txt"
d=data_struc(filename)
p=plotResolutions(d)
filename2 = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_disp_new.txt"
d_dnew=data_struc(filename2)
p_dnew=plotResolutions(d_dnew)
filename3 = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_disp_old.txt"
d_dold=data_struc(filename3)
p_dold=plotResolutions(d_dold)

filename_na = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_geo_na.txt"
d_na=data_struc(filename_na)
p_na=plotResolutions(d_na)
filename2_na = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_disp_new_na.txt"
d_dnew_na=data_struc(filename2_na)
p_dnew_na=plotResolutions(d_dnew_na)
filename3_na = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_disp_old_na.txt"
d_dold_na=data_struc(filename3_na)
p_dold_na=plotResolutions(d_dold_na)

p.set_linestyle('-.')
p_dnew.set_linestyle(':')
p_dold.set_linestyle('--')

p_na.set_linestyle('-.')
p_dnew_na.set_linestyle(':')
p_dold_na.set_linestyle('--')


noise=350

# %%
filename_i = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_geo_ImpactCut.txt"
d_i=data_struc(filename_i)
p_i=plotResolutions(d_i)
filename2_i = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_disp_new_ImpactCut.txt"
d_dnew_i=data_struc(filename2_i)
p_dnew_i=plotResolutions(d_dnew_i)
filename3_i = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_disp_old_ImpactCut.txt"
d_dold_i=data_struc(filename3_i)
p_dold_i=plotResolutions(d_dold_i)

filename_na_i = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_geo_na_ImpactCut.txt"
d_na_i=data_struc(filename_na_i)
p_na_i=plotResolutions(d_na_i)
filename2_na_i = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_disp_new_na_ImpactCut.txt"
d_dnew_na_i=data_struc(filename2_na_i)
p_dnew_na_i=plotResolutions(d_dnew_na_i)
# filename3_na_i = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_disp_old_na_ImpactCut.txt"
# d_dold_na_i=data_struc(filename3_na_i)
# p_dold_na_i=plotResolutions(d_dold_na_i)

p_i.set_linestyle('-.')
p_dnew_i.set_linestyle(':')
p_dold_i.set_linestyle('--')

p_na_i.set_linestyle('-.')
p_dnew_na_i.set_linestyle(':')
# p_dold_na_i.set_linestyle('--')

# %% [raw]
# Comparing disp_new and geo at offset 0.50 and zen 60.

# %%
p.single_zenith(20,50,noise,"res",marker="^")
p.single_zenith(60,50,noise,"res",color='r',marker="^")
p_dnew.single_zenith(60,50,noise,"res",color='r',marker="o")
#p_dold.single_zenith(60,50,noise,"res",color='r',marker="x")

p_na.single_zenith(60,50,noise,"res",color='b',marker="^",extra_label="V5")
p_dnew_na.single_zenith(60,50,noise,"res",color='b',marker="o",extra_label="V5")
#p_dold_na.single_zenith(60,50,noise,"res",color='g',marker="x")

plt.xlim([1e2,1e5])

# %%
filename_g2 = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_geo2.txt"
d_2=data_struc(filename_g2)
p_2=plotResolutions(d_2)

filename_dn2 = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_disp_new2.txt"
d_dnew2=data_struc(filename_dn2)
p_dnew2=plotResolutions(d_dnew2)

filename_do2 = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_disp_old2.txt"
d_dold2=data_struc(filename_do2)
p_dold2=plotResolutions(d_dold2)

p_2.set_colormap("nipy_spectral")
p_2.set_linestyle('-.')
p_dnew2.set_colormap("nipy_spectral")
p_dnew2.set_linestyle(':')
p_dold2.set_colormap("nipy_spectral")
p_dold2.set_linestyle('--')

# %%
wobble=50
plt.figure(0,figsize=[6,4])
p_dnew.xlim=[1e2,1e5]
p_dnew_na.xlim=[1e2,1e5]
n=len(d_na.get_parameters("zenith"))

print "V5 v V6, for both geo and disp_new"
for i in range(n):
    z=d_na.get_parameters("zenith")[i]
    plt.figure(i,figsize=[6,4])
    plt.title("Geo v DispNew "+str(z)+" offset "+str(wobble))
    p.single_zenith(z,wobble,noise,"res",color="r",figure=i,extra_label="V6")
    p_na.single_zenith(z,wobble,noise,"res",color="r",figure=i,extra_label="V5")
    p_dnew.single_zenith(z,wobble,noise,"res",color="g",figure=i ,extra_label="V6")
    p_dnew_na.single_zenith(z,wobble,noise,"res",color="b", figure=i,extra_label="V5")

print "disp_new v disp_old for V5"
for j in range(n):
    i=j+n
    z=d_na.get_parameters("zenith")[j]
    plt.figure(i,figsize=[6,4])
    plt.title("DispOld v DispNew "+str(z)+" offset "+str(wobble))
#     p.single_zenith(z,wobble,noise,"res",color="r",figure=i,extra_label="V6")
#     p_na.single_zenith(z,wobble,noise,"res",color="r",figure=i,extra_label="V5")
    p_dold_na.single_zenith(z,wobble,noise,"res",color="r",figure=i ,extra_label="V5")
    p_dnew_na.single_zenith(z,wobble,noise,"res",color="b", figure=i,extra_label="V5")
# Out:
# V5 v V6, for both geo and disp_new
# disp_new v disp_old for V5

# %%
wobble=50
plt.figure(0,figsize=[14,10])
p_dnew_i.xlim=[1e2,1e5]
p_dnew_na_i.xlim=[1e2,1e5]
n=len(d_na_i.get_parameters("zenith"))

print "V5 v V6, for both geo and disp_new"

p.set_linestyle("-")
p_na.set_linestyle("-")
p_dnew.set_linestyle("-")
p_dnew_na.set_linestyle("-")

p_i.set_linestyle("-.")
p_na_i.set_linestyle("-.")
p_dnew_i.set_linestyle("-.")
p_dnew_na_i.set_linestyle("-.")

for i in range(n):
    z=d_na_i.get_parameters("zenith")[i]
    plt.figure(i,figsize=[14,10])
    plt.title("Geo v DispNew "+str(z)+" offset "+str(wobble))
    p_i.single_zenith(z,wobble,noise,"res",color="r",figure=i,extra_label="V6_ImpactCut")
    p_na_i.single_zenith(z,wobble,noise,"res",color="y",figure=i,extra_label="V5_ImpactCut")
    p_dnew_i.single_zenith(z,wobble,noise,"res",color="g",figure=i ,extra_label="V6_ImpactCut")
    p_dnew_na_i.single_zenith(z,wobble,noise,"res",color="b", figure=i,extra_label="V5_ImpactCut")
    plt.xlim([1e2,1e5])
    plt.ylim([0,.4])
    
for i in range(n):
    z=d_na.get_parameters("zenith")[i]
    plt.figure(i,figsize=[6,4])
    plt.title("Geo v DispNew "+str(z)+" offset "+str(wobble))
    p.single_zenith(z,wobble,noise,"res",color="r",figure=i,extra_label="V6")
    p_na.single_zenith(z,wobble,noise,"res",color="y",figure=i,extra_label="V5")
    p_dnew.single_zenith(z,wobble,noise,"res",color="g",figure=i ,extra_label="V6")
    p_dnew_na.single_zenith(z,wobble,noise,"res",color="b", figure=i,extra_label="V5")
    plt.xlim([1e2,1e5])
    plt.ylim([0,.4])
    
# for j in range(n):
#     i=j+n
#     z=d_na.get_parameters("zenith")[j]
#     plt.figure(i,figsize=[6,4])
#     plt.title("DispOld v DispNew "+str(z)+" offset "+str(wobble))
# #     p.single_zenith(z,wobble,noise,"res",color="r",figure=i,extra_label="V6")
# #     p_na.single_zenith(z,wobble,noise,"res",color="r",figure=i,extra_label="V5")
#     p_dold_na.single_zenith(z,wobble,noise,"res",color="r",figure=i ,extra_label="V5_ImpactCut")
#     p_dnew_na.single_zenith(z,wobble,noise,"res",color="b", figure=i,extra_label="V5_ImpactCut")
# Out:
# V5 v V6, for both geo and disp_new

# %%
plt.figure(0,figsize=[14,10])
plt.figure(1,figsize=[14,10])
p.set_linestyle('-')
p_dnew.set_linestyle('-')
p.single_zenith(20,50,noise,"res",figure=0,color='k',marker='^')
p.single_zenith(60,50,noise,"res",figure=0,color='r',marker='^')
p_dnew.single_zenith(60,50,noise,"res",figure=0,color='r',marker='o')
plt.xlim([1e2,1e5])
plt.ylim([0,.3])
p.single_zenith(20,50,noise,"res",figure=1,color='k',marker='^')
p.single_zenith(65,50,noise,"res",figure=1,color='c',marker='^')
p_dnew.single_zenith(65,50,noise,"res",figure=1,color='c',marker='o')

p_i.set_linestyle('-.')
p_dnew_i.set_linestyle('-.')
p_i.single_zenith(20,50,noise,"res",figure=0,color='k',marker='^',extra_label="ImpactCut")
p_i.single_zenith(60,50,noise,"res",figure=0,color='r',marker='^',extra_label="ImpactCut")
p_dnew_i.single_zenith(60,50,noise,"res",figure=0,color='r',marker='o',extra_label="ImpactCut")
plt.xlim([1e2,1e5])
plt.ylim([0,.3])
p_i.single_zenith(20,50,noise,"res",figure=1,color='k',marker='^',extra_label="ImpactCut")
p_i.single_zenith(65,50,noise,"res",figure=1,color='c',marker='^',extra_label="ImpactCut")
p_dnew_i.single_zenith(65,50,noise,"res",figure=1,color='c',marker='o',extra_label="ImpactCut")

plt.xlim([1e2,1e5])
plt.ylim([0,.4])
# Out:
# (0, 0.4)
