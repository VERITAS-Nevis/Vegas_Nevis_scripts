# %%
# %matplotlib inline
from resolutionPlottingData import *

filename = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_geo.txt"
d=data_struc(filename)
p=plotResolutions(d)
filename2 = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_disp_new.txt"
d_dnew=data_struc(filename2)
p_dnew=plotResolutions(d_dnew)
filename3 = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_disp_old.txt"
d_dold=data_struc(filename3)
p_dold=plotResolutions(d_dold)

p.set_linestyle('-.')
p_dnew.set_linestyle(':')
p_dold.set_linestyle('--')

noise=350
# Out:
# I am being imported from another module

# %% [raw]
# Comparison of Geo, Disp new and Disp old Methods for event reconstruction

# %% [raw]
# This is done by plotting the resolution per energy bin for various simulations. The resolution is the 68% containment radius of the data, from the source center.

# %% [raw]
# Geo Method:

# %% [raw]
# First: compare the calculation of resolution using 2 methods available:
# RMS and Res methods

# %% [raw]
# RMS is calculated by calculating STD of the arrival angles.

# %% [raw]
# Res is calculated by arranging all the events (those in the specified energy bin) in order of angle, then picking the 68% bin.

# %% [raw]
# Looking at wobble = 000

# %%
p.vary_zeniths(3,wobble=0, noise=noise,resolution="res")
plt.title("Wobble 000 - res")

# %%
p.vary_zeniths(4,wobble=0, noise=noise,marker='^',resolution="rms")
plt.title("Wobble 000 - rms")
plt.show()

# %% [raw]
# Looking at wobble = 0.50

# %%
p.vary_zeniths(1,wobble=50,noise=noise,resolution="res")
plt.title("Wobble 050 - res")

# %%
p.vary_zeniths(2,wobble=50,noise=noise,marker='^',resolution='rms')
plt.title("Wobble 050 - rms")
plt.show()

# %% [raw]
# Here are both wobbles on same plot:

# %%
plt.figure(1,figsize=[14,10])
p.vary_zeniths(1,noise=noise)
p.vary_zeniths(1,wobble=0, noise=noise,marker='^')
plt.title("Wobble 0(^) and 0.5 (o) - Res Method")
plt.show()

# %%
plt.figure(2,figsize=[14,10])
p.vary_zeniths(2,noise=noise,resolution="rms")
p.vary_zeniths(2,wobble=0, noise=noise,marker='^',resolution="rms")
plt.title("Wobble 0(^) and 0.5 (o) (RMS Method)")
plt.show()

# %% [raw]
# Higher wobbles for GEO method (all res method):

# %%
p.vary_zeniths(4,wobble=100, noise=noise)
plt.title("Wobble 100 - res")
plt.show()

# %%
p.vary_zeniths(5,wobble=150, noise=noise)
plt.title("Wobble 150 - res")
plt.show()

# %%
p.vary_zeniths(6,wobble=200, noise=noise)
plt.title("Wobble 200 - res")
plt.show()

# %% [raw]
# Checking the higher wobble for the RMS method as well

# %%
p.vary_zeniths(4,wobble=100,noise=noise,resolution="rms")
plt.title("RMS - Wobble 100")
plt.show()

# %%
p.vary_zeniths(5,wobble=150, noise=noise,resolution="rms")
plt.title("RMS - Wobble 150")
plt.show()

# %%
p.vary_zeniths(6,wobble=200, noise=noise,resolution="rms")
plt.title("RMS - Wobble 200")
plt.show()

# %% [raw]
# Disp_new:

# %% [raw]
# All wobbles, using res method

# %%
p_dnew.vary_zeniths(1,wobble=0  ,noise=noise,resolution="res")
#p.vary_zeniths(1,wobble=0  ,noise=noise,resolution="res", marker='^')
plt.title("Wobble 000")
plt.show()

# %%
p_dnew.vary_zeniths(2,wobble=0  ,noise=noise,resolution="res")
#p.vary_zeniths(2,wobble=0  ,noise=noise,resolution="res", marker='^')
plt.ylim([0,0.5])
plt.title("Wobble 000 - Resized")
plt.show()

# %%
p_dnew.vary_zeniths(3,wobble=50 ,noise=noise,resolution="res")
#p.vary_zeniths(3,wobble=50 ,noise=noise,resolution="res", marker='^')
plt.title("Wobble 050")
plt.show()

# %%
p_dnew.vary_zeniths(4,wobble=100,noise=noise,resolution="res")
#p.vary_zeniths(4,wobble=100,noise=noise,resolution="res", marker='^')
plt.title("Wobble 100")
plt.show()

# %%
p_dnew.vary_zeniths(5,wobble=150,noise=noise,resolution="res")
#p.vary_zeniths(5,wobble=150,noise=noise,resolution="res", marker='^')
plt.title("Wobble 150")
plt.show()

# %%
p_dnew.vary_zeniths(6,wobble=200,noise=noise,resolution="res")
#p.vary_zeniths(6,wobble=200,noise=noise,resolution="res", marker='^')
plt.title("Wobble 200")
plt.show()

# %% [raw]
# Disp Old:

# %% [raw]
# All wobbles, using res method

# %%
# p_dnew.vary_zeniths(1,wobble=0  ,noise=noise,resolution="res")
# p.vary_zeniths(1,wobble=0  ,noise=noise,resolution="res", marker='^')
p_dold.vary_zeniths(1,wobble=0  ,noise=noise,resolution="res", marker='o')
plt.title("Wobble 000")
plt.show()

# %%
# p_dnew.vary_zeniths(2,wobble=0  ,noise=noise,resolution="res")
# p.vary_zeniths(2,wobble=0  ,noise=noise,resolution="res", marker='^')
p_dold.vary_zeniths(2,wobble=0  ,noise=noise,resolution="res", marker='o')
plt.ylim([0,0.5])
plt.title("Wobble 000 - Resized")
plt.show()

# %%
# p_dnew.vary_zeniths(3,wobble=50 ,noise=noise,resolution="res")
# p.vary_zeniths(3,wobble=50 ,noise=noise,resolution="res", marker='^')
p_dold.vary_zeniths(3,wobble=50 ,noise=noise,resolution="res", marker='o')
plt.title("Wobble 050")
plt.show()

# %%
# p_dnew.vary_zeniths(4,wobble=100,noise=noise,resolution="res")
# p.vary_zeniths(4,wobble=100,noise=noise,resolution="res", marker='^')
p_dold.vary_zeniths(4,wobble=100,noise=noise,resolution="res", marker='o')
plt.title("Wobble 100")
plt.show()

# %%
# p_dnew.vary_zeniths(5,wobble=150,noise=noise,resolution="res")
# p.vary_zeniths(5,wobble=150,noise=noise,resolution="res", marker='^')
p_dold.vary_zeniths(5,wobble=150,noise=noise,resolution="res", marker='o')
plt.title("Wobble 150")
plt.show()

# %%
# p_dnew.vary_zeniths(6,wobble=200,noise=noise,resolution="res")
# p.vary_zeniths(6,wobble=200,noise=noise,resolution="res", marker='^')
p_dold.vary_zeniths(6,wobble=200,noise=noise,resolution="res", marker='o')
plt.title("Wobble 200")
plt.show()

# %% [raw]
# Geo:

# %% [raw]
# All wobbles, using res method

# %%
#p_dnew.vary_zeniths(1,wobble=0  ,noise=noise,resolution="res")
p.vary_zeniths(1,wobble=0  ,noise=noise,resolution="res", marker='^')
#p_dold.vary_zeniths(1,wobble=0  ,noise=noise,resolution="res", marker='*')
plt.title("Wobble 000")
plt.show()

# %%
# p_dnew.vary_zeniths(2,wobble=0  ,noise=noise,resolution="res")
p.vary_zeniths(2,wobble=0  ,noise=noise,resolution="res", marker='^')
#p_dold.vary_zeniths(2,wobble=0  ,noise=noise,resolution="res", marker='*')
plt.ylim([0,0.5])
plt.title("Wobble 000 - Resized")
plt.show()

# %%
p.vary_zeniths(6,wobble=50,noise=noise,resolution="res", marker='^')
plt.title("Wobble 050")
plt.show()

# %%
p.vary_zeniths(6,wobble=100,noise=noise,resolution="res", marker='^')
plt.title("Wobble 100")
plt.show()

# %%
p.vary_zeniths(6,wobble=150,noise=noise,resolution="res", marker='^')
plt.title("Wobble 150")
plt.show()

# %%
p.vary_zeniths(6,wobble=200,noise=noise,resolution="res", marker='^')
plt.title("Wobble 200")
plt.show()

# %% [raw]
# Some Practice commands

# %%
p_dnew.vary_zeniths(1,wobble=200,noise=noise, resolution="res",marker="^")
p_dold.vary_zeniths(1,wobble=200,noise=noise, resolution="res",marker="o")
plt.xlim([1e2,1e4])
plt.ylim([0.1,0.30])

# p.vary_zeniths(1,wobble=50,noise=noise, resolution="res",marker="*")
# Out:
# (0.1, 0.3)

# %%
p.single_zenith(20,50,noise,"res",marker="^")
p.single_zenith(60,50,noise,"res")
p_dnew.single_zenith(60,50,noise,"res",color='r')
p_dold.single_zenith(60,50,noise,"res",color='g')
plt.xlim([1e2,1e5])
# Out:
# (100.0, 100000.0)

# %%
p.single_zenith(20,50,noise,"res",marker="^")
p.single_zenith(65,50,noise,"res")
p_dnew.single_zenith(65,50,noise,"res",color='r')
p_dold.single_zenith(65,50,noise,"res",color='g')
plt.xlim([1e2,1e5])
# Out:
# (100.0, 100000.0)

# %% [raw]
# Redoing with the fEnergyGeV flag

# %% [raw]
# Sim energy, not reconstructed

# %%
filename_g2 = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_geo2.txt"
d_2=data_struc(filename_g2)
p_2=plotResolutions(d_2)

filename_dn2 = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_disp_new2.txt"
d_dnew2=data_struc(filename_dn2)
p_dnew2=plotResolutions(d_dnew2)

filename_do2 = "/a/home/tehanu/dribeiro/Analysis/CrabSim/runlists/Classes/Results_disp_old2.txt"
d_dold2=data_struc(filename_do2)
p_dold2=plotResolutions(d_dold2)

p_2.set_colormap("nipy_spectral")
p_2.set_linestyle('-.')
p_dnew2.set_colormap("nipy_spectral")
p_dnew2.set_linestyle(':')
p_dold2.set_colormap("nipy_spectral")
p_dold2.set_linestyle('--')

# %% [raw]
# Disp New:

# %%
p_dnew2.vary_zeniths(6,wobble=50,noise=noise,resolution="res")
plt.title("Wobble 050")
plt.show()

# %% [raw]
# Disp Old:

# %%
p_dold2.vary_zeniths(6,wobble=50,noise=noise,resolution="res")
plt.title("Wobble 050")
plt.show()

# %% [raw]
# Geo

# %%
p_2.vary_zeniths(6,wobble=50,noise=noise,resolution="res")
plt.title("Wobble 050")
plt.show()
